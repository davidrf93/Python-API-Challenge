# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                        City      Lat       Lng  Max Temp  Humidity  \
# 0        0                     tondano   1.3038  124.9112     21.05        94
# 1        1               ribeira brava  32.6500  -17.0667     27.35        61
# 2        2                        mili   6.0815  171.7350     27.21        81
# 3        3                      oppdal  62.5943    9.6912     13.59        96
# 4        4  helena valley west central  46.6629 -112.0604     22.62        57
#
#    Cloudiness  Wind Speed Country        Date
# 0          52        1.64      ID  1691514137
# 1           0        3.38      PT  1691514138
# 2         100        5.08      MH  1691514140
# 3         100        2.52      NO  1691514141
# 4           2        1.79      US  1691514142

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()

#%%capture --no-display
# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600,
    scale = 0.5,
    color = "City"
)
# Display the map
map_plot
# Out:
# C:\Users\david\anaconda3\envs\dev\lib\site-packages\geoviews\operation\__init__.py:14: HoloviewsDeprecationWarning: 'ResamplingOperation' is deprecated and will be removed in version 1.18, use 'ResampleOperation2D' instead.
#   from holoviews.operation.datashader import (
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
min_temp_s = city_data_df["Max Temp"] > 21
max_temp_s = city_data_df["Max Temp"] < 27
wind_speed_s = city_data_df["Wind Speed"] > 5

# %%
print(sum(min_temp_s))
print(sum(max_temp_s))
print(sum(wind_speed_s))
# Out:
# 352
# 402
# 165

# %%
# A max temperature lower than 27 degrees but higher than 21
# Wind speed more than 5 m/s

# Narrow down cities that fit criteria and drop any results with null values
# Max temp
city_temp_range_df = city_data_df[min_temp_s & max_temp_s & wind_speed_s]
city_temp_range_df

# Drop any rows with null values & Display sample data
clean_city_temp_range_df = city_temp_range_df.dropna()
clean_city_temp_range_df
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 11        11                   kismayo  -0.3582   42.5454     24.56        82
# 14        14                 adamstown -25.0660 -130.1015     22.27        87
# 17        17             port mathurin -19.6833   63.4167     22.67        71
# 23        23                      sola -13.8833  167.5500     24.74        83
# 29        29                 jamestown  42.0970  -79.2353     23.07        68
# 30        30               west island -12.1568   96.8225     25.99        83
# 41        41            ribeira grande  38.5167  -28.7000     24.87        78
# 42        42                    hadibu  12.6500   54.0333     26.00        77
# 49        49               nova sintra  14.8667  -24.7167     22.54        74
# 60        60  sao jose da coroa grande  -8.8978  -35.1478     24.98        83
# 68        68          flying fish cove -10.4217  105.6791     24.82        83
# 71        71                nouadhibou  20.9310  -17.0347     25.99        65
# 87        87             haiku-pauwela  20.9219 -156.3051     25.58        68
# 94        94              anuradhapura   8.3565   80.4173     25.98        81
# 105      105         cornelio procopio -23.1811  -50.6467     24.58        46
# 120      120               beau vallon -20.4189   57.6953     23.13        64
# 129      129                    dakhla  23.6848  -15.9580     25.01        69
# 136      136         wailua homesteads  22.0669 -159.3780     26.44        82
# 140      140         sao joao da barra -21.6403  -41.0511     25.05        67
# 151      151                 ceeldheer   3.8488   47.1806     24.61        81
# 152      152           arraial do cabo -22.9661  -42.0278     23.92        78
# 156      156       san antonio de pale  -1.4014    5.6325     23.40        75
# 178      178                     lihue  21.9789 -159.3672     26.77        77
# 181      181                     pisco -13.7000  -76.2167     21.03        68
# 189      189                    touros  -5.1989  -35.4608     26.33        76
# 194      194                 saynshand  44.8824  110.1163     22.73        48
# 218      218                      daru  -9.0763  143.2092     24.20        78
# 306      306                 al qubbah  32.7616   22.2424     22.06        69
# 321      321                 hammonton  39.6365  -74.8024     25.95        74
# 338      338                vila velha -20.3297  -40.2925     25.97        81
# 339      339                     horta  38.5333  -28.6333     24.45        82
# 346      346               antsiranana -12.2787   49.2917     22.69        81
# 375      375                   veraval  20.9000   70.3667     26.98        84
# 390      390   puerto baquerizo moreno  -0.9000  -89.6000     23.99        74
# 392      392                   harstad  68.7990   16.5293     26.66        71
# 405      405                   sal rei  16.1833  -22.9167     25.62        70
# 424      424         caleta de carquin -11.0925  -77.6267     21.93        67
# 446      446               robertsport   6.7533  -11.3686     25.90        85
# 454      454                 paramonga -10.6667  -77.8333     21.83        69
# 464      464             ponta delgada  37.7333  -25.6667     24.40        69
# 490      490                     marka   1.7159   44.7717     24.50        84
# 492      492                       eyl   7.9803   49.8164     25.18        79
# 499      499                    bonthe   7.5264  -12.5050     26.83        80
# 501      501                   chhabra  24.6667   76.8333     26.24        77
# 510      510                hammerfest  70.6634   23.6821     24.25        69
# 532      532                     alofi -19.0595 -169.9187     24.06        88
# 542      542                    harper   4.3750   -7.7169     25.15        83
# 555      555                pudasjarvi  65.3833   26.9167     22.31        80
# 561      561                      naze  28.3667  129.4833     25.97        92
# 572      572                      gizo  -8.1030  156.8419     25.89        85
#
#      Cloudiness  Wind Speed Country        Date
# 11            5        7.13      SO  1691514149
# 14           98       12.56      PN  1691514152
# 17           19        9.44      MU  1691514155
# 23          100        8.46      VU  1691514082
# 29           75       11.32      US  1691513988
# 30           40        6.69      CC  1691514171
# 41           40        5.81      PT  1691514181
# 42           57        8.25      YE  1691514182
# 49           10        7.38      CV  1691514189
# 60           83        5.08      BR  1691514200
# 68          100        5.66      CX  1691514209
# 71            0        9.77      MR  1691514211
# 87           40        8.23      US  1691514227
# 94           92        5.02      LK  1691514234
# 105          86        5.76      BR  1691514246
# 120          40        6.17      MU  1691514260
# 129           0        8.23      EH  1691514270
# 136         100        8.23      US  1691514278
# 140           8        9.30      BR  1691514246
# 151          47        9.65      SO  1691514294
# 152          75        6.17      BR  1691514073
# 156          27        5.06      GQ  1691514076
# 178         100        8.23      US  1691514334
# 181           0        5.14      PE  1691514287
# 189          37        7.95      BR  1691514064
# 194           4        5.74      MN  1691514349
# 218         100        7.18      PG  1691514374
# 306           0        9.40      LY  1691514462
# 321          35        6.84      US  1691514294
# 338          40        7.20      BR  1691514495
# 339          40        5.81      PT  1691514496
# 346           9        5.41      MG  1691514442
# 375         100        8.18      IN  1691514532
# 390          96        5.80      EC  1691514547
# 392          28        7.15      NO  1691514549
# 405          47        6.16      CV  1691514561
# 424          10        5.63      PE  1691514578
# 446          96        6.74      LR  1691514600
# 454          15        5.44      PE  1691514609
# 464          40        5.66      PT  1691514619
# 490          41        6.63      SO  1691514649
# 492          88       11.87      SO  1691514651
# 499          80        5.75      SL  1691514657
# 501         100        5.29      IN  1691514659
# 510           0        5.14      NO  1691514403
# 532          43        5.39      NU  1691514690
# 542          96        5.74      LR  1691514700
# 555          10        5.34      FI  1691514713
# 561         100       12.22      JP  1691514719
# 572          99        6.77      SB  1691514732

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_city_temp_range_df.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 11        11                   kismayo  -0.3582   42.5454     24.56        82
# 14        14                 adamstown -25.0660 -130.1015     22.27        87
# 17        17             port mathurin -19.6833   63.4167     22.67        71
# 23        23                      sola -13.8833  167.5500     24.74        83
# 29        29                 jamestown  42.0970  -79.2353     23.07        68
# 30        30               west island -12.1568   96.8225     25.99        83
# 41        41            ribeira grande  38.5167  -28.7000     24.87        78
# 42        42                    hadibu  12.6500   54.0333     26.00        77
# 49        49               nova sintra  14.8667  -24.7167     22.54        74
# 60        60  sao jose da coroa grande  -8.8978  -35.1478     24.98        83
# 68        68          flying fish cove -10.4217  105.6791     24.82        83
# 71        71                nouadhibou  20.9310  -17.0347     25.99        65
# 87        87             haiku-pauwela  20.9219 -156.3051     25.58        68
# 94        94              anuradhapura   8.3565   80.4173     25.98        81
# 105      105         cornelio procopio -23.1811  -50.6467     24.58        46
# 120      120               beau vallon -20.4189   57.6953     23.13        64
# 129      129                    dakhla  23.6848  -15.9580     25.01        69
# 136      136         wailua homesteads  22.0669 -159.3780     26.44        82
# 140      140         sao joao da barra -21.6403  -41.0511     25.05        67
# 151      151                 ceeldheer   3.8488   47.1806     24.61        81
# 152      152           arraial do cabo -22.9661  -42.0278     23.92        78
# 156      156       san antonio de pale  -1.4014    5.6325     23.40        75
# 178      178                     lihue  21.9789 -159.3672     26.77        77
# 181      181                     pisco -13.7000  -76.2167     21.03        68
# 189      189                    touros  -5.1989  -35.4608     26.33        76
# 194      194                 saynshand  44.8824  110.1163     22.73        48
# 218      218                      daru  -9.0763  143.2092     24.20        78
# 306      306                 al qubbah  32.7616   22.2424     22.06        69
# 321      321                 hammonton  39.6365  -74.8024     25.95        74
# 338      338                vila velha -20.3297  -40.2925     25.97        81
# 339      339                     horta  38.5333  -28.6333     24.45        82
# 346      346               antsiranana -12.2787   49.2917     22.69        81
# 375      375                   veraval  20.9000   70.3667     26.98        84
# 390      390   puerto baquerizo moreno  -0.9000  -89.6000     23.99        74
# 392      392                   harstad  68.7990   16.5293     26.66        71
# 405      405                   sal rei  16.1833  -22.9167     25.62        70
# 424      424         caleta de carquin -11.0925  -77.6267     21.93        67
# 446      446               robertsport   6.7533  -11.3686     25.90        85
# 454      454                 paramonga -10.6667  -77.8333     21.83        69
# 464      464             ponta delgada  37.7333  -25.6667     24.40        69
# 490      490                     marka   1.7159   44.7717     24.50        84
# 492      492                       eyl   7.9803   49.8164     25.18        79
# 499      499                    bonthe   7.5264  -12.5050     26.83        80
# 501      501                   chhabra  24.6667   76.8333     26.24        77
# 510      510                hammerfest  70.6634   23.6821     24.25        69
# 532      532                     alofi -19.0595 -169.9187     24.06        88
# 542      542                    harper   4.3750   -7.7169     25.15        83
# 555      555                pudasjarvi  65.3833   26.9167     22.31        80
# 561      561                      naze  28.3667  129.4833     25.97        92
# 572      572                      gizo  -8.1030  156.8419     25.89        85
#
#      Cloudiness  Wind Speed Country        Date Hotel Name
# 11            5        7.13      SO  1691514149
# 14           98       12.56      PN  1691514152
# 17           19        9.44      MU  1691514155
# 23          100        8.46      VU  1691514082
# 29           75       11.32      US  1691513988
# 30           40        6.69      CC  1691514171
# 41           40        5.81      PT  1691514181
# 42           57        8.25      YE  1691514182
# 49           10        7.38      CV  1691514189
# 60           83        5.08      BR  1691514200
# 68          100        5.66      CX  1691514209
# 71            0        9.77      MR  1691514211
# 87           40        8.23      US  1691514227
# 94           92        5.02      LK  1691514234
# 105          86        5.76      BR  1691514246
# 120          40        6.17      MU  1691514260
# 129           0        8.23      EH  1691514270
# 136         100        8.23      US  1691514278
# 140           8        9.30      BR  1691514246
# 151          47        9.65      SO  1691514294
# 152          75        6.17      BR  1691514073
# 156          27        5.06      GQ  1691514076
# 178         100        8.23      US  1691514334
# 181           0        5.14      PE  1691514287
# 189          37        7.95      BR  1691514064
# 194           4        5.74      MN  1691514349
# 218         100        7.18      PG  1691514374
# 306           0        9.40      LY  1691514462
# 321          35        6.84      US  1691514294
# 338          40        7.20      BR  1691514495
# 339          40        5.81      PT  1691514496
# 346           9        5.41      MG  1691514442
# 375         100        8.18      IN  1691514532
# 390          96        5.80      EC  1691514547
# 392          28        7.15      NO  1691514549
# 405          47        6.16      CV  1691514561
# 424          10        5.63      PE  1691514578
# 446          96        6.74      LR  1691514600
# 454          15        5.44      PE  1691514609
# 464          40        5.66      PT  1691514619
# 490          41        6.63      SO  1691514649
# 492          88       11.87      SO  1691514651
# 499          80        5.75      SL  1691514657
# 501         100        5.29      IN  1691514659
# 510           0        5.14      NO  1691514403
# 532          43        5.39      NU  1691514690
# 542          96        5.74      LR  1691514700
# 555          10        5.34      FI  1691514713
# 561         100       12.22      JP  1691514719
# 572          99        6.77      SB  1691514732

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
limit = 1
categories = "accommodation.hotel"

#create a params dictionary
params = {
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lng = hotel_df.loc[index, "Lng"]
    lat = hotel_df.loc[index, "Lat"]
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"
    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    print(name_address.url)
    # Convert the API response to JSON format
    name_address = name_address.json()
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
# Display sample data
hotel_df
# Out:
# Starting hotel search
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A42.5454%2C-0.3582%2C10000&bias=proximity%3A42.5454%2C-0.3582
# kismayo - nearest hotel: Kismayo Hotel
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-130.1015%2C-25.066%2C10000&bias=proximity%3A-130.1015%2C-25.066
# adamstown - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A63.4167%2C-19.6833%2C10000&bias=proximity%3A63.4167%2C-19.6833
# port mathurin - nearest hotel: Escale Vacances
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A167.55%2C-13.8833%2C10000&bias=proximity%3A167.55%2C-13.8833
# sola - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-79.2353%2C42.097%2C10000&bias=proximity%3A-79.2353%2C42.097
# jamestown - nearest hotel: DoubleTree Jamestown
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A96.8225%2C-12.1568%2C10000&bias=proximity%3A96.8225%2C-12.1568
# west island - nearest hotel: Cocos Village Bungalows
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-28.7%2C38.5167%2C10000&bias=proximity%3A-28.7%2C38.5167
# ribeira grande - nearest hotel: Hospedaria JSF
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A54.0333%2C12.65%2C10000&bias=proximity%3A54.0333%2C12.65
# hadibu - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-24.7167%2C14.8667%2C10000&bias=proximity%3A-24.7167%2C14.8667
# nova sintra - nearest hotel: Residência Ka Dencho
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-35.1478%2C-8.8978%2C10000&bias=proximity%3A-35.1478%2C-8.8978
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A105.6791%2C-10.4217%2C10000&bias=proximity%3A105.6791%2C-10.4217
# flying fish cove - nearest hotel: Christmas Island Lodge
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-17.0347%2C20.931%2C10000&bias=proximity%3A-17.0347%2C20.931
# nouadhibou - nearest hotel: Hotel valencia
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-156.3051%2C20.9219%2C10000&bias=proximity%3A-156.3051%2C20.9219
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A80.4173%2C8.3565%2C10000&bias=proximity%3A80.4173%2C8.3565
# anuradhapura - nearest hotel: N & L Holiday Resort
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-50.6467%2C-23.1811%2C10000&bias=proximity%3A-50.6467%2C-23.1811
# cornelio procopio - nearest hotel: Hotel Midas
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A57.6953%2C-20.4189%2C10000&bias=proximity%3A57.6953%2C-20.4189
# beau vallon - nearest hotel: Le Jardin de Beau Vallon
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-15.958%2C23.6848%2C10000&bias=proximity%3A-15.958%2C23.6848
# dakhla - nearest hotel: Hotel El Massira
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-159.378%2C22.0669%2C10000&bias=proximity%3A-159.378%2C22.0669
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-41.0511%2C-21.6403%2C10000&bias=proximity%3A-41.0511%2C-21.6403
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A47.1806%2C3.8488%2C10000&bias=proximity%3A47.1806%2C3.8488
# ceeldheer - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-42.0278%2C-22.9661%2C10000&bias=proximity%3A-42.0278%2C-22.9661
# arraial do cabo - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A5.6325%2C-1.4014%2C10000&bias=proximity%3A5.6325%2C-1.4014
# san antonio de pale - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-159.3672%2C21.9789%2C10000&bias=proximity%3A-159.3672%2C21.9789
# lihue - nearest hotel: Kauai Palms
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-76.2167%2C-13.7%2C10000&bias=proximity%3A-76.2167%2C-13.7
# pisco - nearest hotel: La Portada
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-35.4608%2C-5.1989%2C10000&bias=proximity%3A-35.4608%2C-5.1989
# touros - nearest hotel: Pousada Atlântico
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A110.1163%2C44.8824%2C10000&bias=proximity%3A110.1163%2C44.8824
# saynshand - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A143.2092%2C-9.0763%2C10000&bias=proximity%3A143.2092%2C-9.0763
# daru - nearest hotel: Kuki
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A22.2424%2C32.7616%2C10000&bias=proximity%3A22.2424%2C32.7616
# al qubbah - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-74.8024%2C39.6365%2C10000&bias=proximity%3A-74.8024%2C39.6365
# hammonton - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-40.2925%2C-20.3297%2C10000&bias=proximity%3A-40.2925%2C-20.3297
# vila velha - nearest hotel: Hotel Prainha
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-28.6333%2C38.5333%2C10000&bias=proximity%3A-28.6333%2C38.5333
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A49.2917%2C-12.2787%2C10000&bias=proximity%3A49.2917%2C-12.2787
# antsiranana - nearest hotel: Central
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A70.3667%2C20.9%2C10000&bias=proximity%3A70.3667%2C20.9
# veraval - nearest hotel: Shyam
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-89.6%2C-0.9%2C10000&bias=proximity%3A-89.6%2C-0.9
# puerto baquerizo moreno - nearest hotel: Dory's House
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A16.5293%2C68.799%2C10000&bias=proximity%3A16.5293%2C68.799
# harstad - nearest hotel: Scandic Harstad
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-22.9167%2C16.1833%2C10000&bias=proximity%3A-22.9167%2C16.1833
# sal rei - nearest hotel: Hotel Marine Club
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-77.6267%2C-11.0925%2C10000&bias=proximity%3A-77.6267%2C-11.0925
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-11.3686%2C6.7533%2C10000&bias=proximity%3A-11.3686%2C6.7533
# robertsport - nearest hotel: Nana's Lodge
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-77.8333%2C-10.6667%2C10000&bias=proximity%3A-77.8333%2C-10.6667
# paramonga - nearest hotel: Hotel Rico
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-25.6667%2C37.7333%2C10000&bias=proximity%3A-25.6667%2C37.7333
# ponta delgada - nearest hotel: Hotel Talisman
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A44.7717%2C1.7159%2C10000&bias=proximity%3A44.7717%2C1.7159
# marka - nearest hotel: Salsabiil Hotel
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A49.8164%2C7.9803%2C10000&bias=proximity%3A49.8164%2C7.9803
# eyl - nearest hotel: فندق ايل دابي
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-12.505%2C7.5264%2C10000&bias=proximity%3A-12.505%2C7.5264
# bonthe - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A76.8333%2C24.6667%2C10000&bias=proximity%3A76.8333%2C24.6667
# chhabra - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A23.6821%2C70.6634%2C10000&bias=proximity%3A23.6821%2C70.6634
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-169.9187%2C-19.0595%2C10000&bias=proximity%3A-169.9187%2C-19.0595
# alofi - nearest hotel: Matavai Resort
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A-7.7169%2C4.375%2C10000&bias=proximity%3A-7.7169%2C4.375
# harper - nearest hotel: No hotel found
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A26.9167%2C65.3833%2C10000&bias=proximity%3A26.9167%2C65.3833
# pudasjarvi - nearest hotel: Hotelli-ravintola Kurenkoski
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A129.4833%2C28.3667%2C10000&bias=proximity%3A129.4833%2C28.3667
# naze - nearest hotel: ビジネス旅館畠山
# https://api.geoapify.com/v2/places?categories=accommodation.hotel&limit=1&apiKey=1b2c9749b7e04f4da39a21e64b9c27ca&filter=circle%3A156.8419%2C-8.103%2C10000&bias=proximity%3A156.8419%2C-8.103
# gizo - nearest hotel: Gizo Hotel
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 11        11                   kismayo  -0.3582   42.5454     24.56        82
# 14        14                 adamstown -25.0660 -130.1015     22.27        87
# 17        17             port mathurin -19.6833   63.4167     22.67        71
# 23        23                      sola -13.8833  167.5500     24.74        83
# 29        29                 jamestown  42.0970  -79.2353     23.07        68
# 30        30               west island -12.1568   96.8225     25.99        83
# 41        41            ribeira grande  38.5167  -28.7000     24.87        78
# 42        42                    hadibu  12.6500   54.0333     26.00        77
# 49        49               nova sintra  14.8667  -24.7167     22.54        74
# 60        60  sao jose da coroa grande  -8.8978  -35.1478     24.98        83
# 68        68          flying fish cove -10.4217  105.6791     24.82        83
# 71        71                nouadhibou  20.9310  -17.0347     25.99        65
# 87        87             haiku-pauwela  20.9219 -156.3051     25.58        68
# 94        94              anuradhapura   8.3565   80.4173     25.98        81
# 105      105         cornelio procopio -23.1811  -50.6467     24.58        46
# 120      120               beau vallon -20.4189   57.6953     23.13        64
# 129      129                    dakhla  23.6848  -15.9580     25.01        69
# 136      136         wailua homesteads  22.0669 -159.3780     26.44        82
# 140      140         sao joao da barra -21.6403  -41.0511     25.05        67
# 151      151                 ceeldheer   3.8488   47.1806     24.61        81
# 152      152           arraial do cabo -22.9661  -42.0278     23.92        78
# 156      156       san antonio de pale  -1.4014    5.6325     23.40        75
# 178      178                     lihue  21.9789 -159.3672     26.77        77
# 181      181                     pisco -13.7000  -76.2167     21.03        68
# 189      189                    touros  -5.1989  -35.4608     26.33        76
# 194      194                 saynshand  44.8824  110.1163     22.73        48
# 218      218                      daru  -9.0763  143.2092     24.20        78
# 306      306                 al qubbah  32.7616   22.2424     22.06        69
# 321      321                 hammonton  39.6365  -74.8024     25.95        74
# 338      338                vila velha -20.3297  -40.2925     25.97        81
# 339      339                     horta  38.5333  -28.6333     24.45        82
# 346      346               antsiranana -12.2787   49.2917     22.69        81
# 375      375                   veraval  20.9000   70.3667     26.98        84
# 390      390   puerto baquerizo moreno  -0.9000  -89.6000     23.99        74
# 392      392                   harstad  68.7990   16.5293     26.66        71
# 405      405                   sal rei  16.1833  -22.9167     25.62        70
# 424      424         caleta de carquin -11.0925  -77.6267     21.93        67
# 446      446               robertsport   6.7533  -11.3686     25.90        85
# 454      454                 paramonga -10.6667  -77.8333     21.83        69
# 464      464             ponta delgada  37.7333  -25.6667     24.40        69
# 490      490                     marka   1.7159   44.7717     24.50        84
# 492      492                       eyl   7.9803   49.8164     25.18        79
# 499      499                    bonthe   7.5264  -12.5050     26.83        80
# 501      501                   chhabra  24.6667   76.8333     26.24        77
# 510      510                hammerfest  70.6634   23.6821     24.25        69
# 532      532                     alofi -19.0595 -169.9187     24.06        88
# 542      542                    harper   4.3750   -7.7169     25.15        83
# 555      555                pudasjarvi  65.3833   26.9167     22.31        80
# 561      561                      naze  28.3667  129.4833     25.97        92
# 572      572                      gizo  -8.1030  156.8419     25.89        85
#
#      Cloudiness  Wind Speed Country        Date  \
# 11            5        7.13      SO  1691514149
# 14           98       12.56      PN  1691514152
# 17           19        9.44      MU  1691514155
# 23          100        8.46      VU  1691514082
# 29           75       11.32      US  1691513988
# 30           40        6.69      CC  1691514171
# 41           40        5.81      PT  1691514181
# 42           57        8.25      YE  1691514182
# 49           10        7.38      CV  1691514189
# 60           83        5.08      BR  1691514200
# 68          100        5.66      CX  1691514209
# 71            0        9.77      MR  1691514211
# 87           40        8.23      US  1691514227
# 94           92        5.02      LK  1691514234
# 105          86        5.76      BR  1691514246
# 120          40        6.17      MU  1691514260
# 129           0        8.23      EH  1691514270
# 136         100        8.23      US  1691514278
# 140           8        9.30      BR  1691514246
# 151          47        9.65      SO  1691514294
# 152          75        6.17      BR  1691514073
# 156          27        5.06      GQ  1691514076
# 178         100        8.23      US  1691514334
# 181           0        5.14      PE  1691514287
# 189          37        7.95      BR  1691514064
# 194           4        5.74      MN  1691514349
# 218         100        7.18      PG  1691514374
# 306           0        9.40      LY  1691514462
# 321          35        6.84      US  1691514294
# 338          40        7.20      BR  1691514495
# 339          40        5.81      PT  1691514496
# 346           9        5.41      MG  1691514442
# 375         100        8.18      IN  1691514532
# 390          96        5.80      EC  1691514547
# 392          28        7.15      NO  1691514549
# 405          47        6.16      CV  1691514561
# 424          10        5.63      PE  1691514578
# 446          96        6.74      LR  1691514600
# 454          15        5.44      PE  1691514609
# 464          40        5.66      PT  1691514619
# 490          41        6.63      SO  1691514649
# 492          88       11.87      SO  1691514651
# 499          80        5.75      SL  1691514657
# 501         100        5.29      IN  1691514659
# 510           0        5.14      NO  1691514403
# 532          43        5.39      NU  1691514690
# 542          96        5.74      LR  1691514700
# 555          10        5.34      FI  1691514713
# 561         100       12.22      JP  1691514719
# 572          99        6.77      SB  1691514732
#
#                              Hotel Name
# 11                        Kismayo Hotel
# 14                       No hotel found
# 17                      Escale Vacances
# 23                       No hotel found
# 29                 DoubleTree Jamestown
# 30              Cocos Village Bungalows
# 41                       Hospedaria JSF
# 42                       No hotel found
# 49                 Residência Ka Dencho
# 60                         Hotel do Sol
# 68               Christmas Island Lodge
# 71                       Hotel valencia
# 87             Inn At Mama's Fish House
# 94                 N & L Holiday Resort
# 105                         Hotel Midas
# 120            Le Jardin de Beau Vallon
# 129                    Hotel El Massira
# 136  Hilton Garden Inn Kauai Wailua Bay
# 140                Pousada Mediterrâneo
# 151                      No hotel found
# 152                      No hotel found
# 156                      No hotel found
# 178                         Kauai Palms
# 181                          La Portada
# 189                   Pousada Atlântico
# 194                      No hotel found
# 218                                Kuki
# 306                      No hotel found
# 321                      No hotel found
# 338                       Hotel Prainha
# 339  Azoris Faial Garden - Resort Hotel
# 346                             Central
# 375                               Shyam
# 390                        Dory's House
# 392                     Scandic Harstad
# 405                   Hotel Marine Club
# 424                    Hotel Mi Choacan
# 446                        Nana's Lodge
# 454                          Hotel Rico
# 464                      Hotel Talisman
# 490                     Salsabiil Hotel
# 492                       فندق ايل دابي
# 499                      No hotel found
# 501                      No hotel found
# 510               Thon Hotel Hammerfest
# 532                      Matavai Resort
# 542                      No hotel found
# 555        Hotelli-ravintola Kurenkoski
# 561                            ビジネス旅館畠山
# 572                          Gizo Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display
# Configure the map plot
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    scale = 0.5,
    color = "City"
)
# Display the map
hotel_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City)
